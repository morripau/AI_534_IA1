# %%
import pandas as pd, os, datetime, copy as cp, numpy as np, matplotlib.pyplot as plt

# %%
def load_data(path):
    # Your code here:
    loaded_data = pd.read_csv(path, parse_dates= ["date"])
    return loaded_data

# %%
train_3 = load_data(training_file_dir)

# %%
preprocess_data(train_3)
# Out:
#       bias  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0        1         3       1.00         1020      7874     1.0           0
# 1        1         3       2.25         2210      8000     2.0           0
# 2        1         4       2.50         2350      5835     2.0           0
# 3        1         3       1.50         1660      4800     2.0           0
# 4        1         3       2.50         2410      9916     2.0           0
# ...    ...       ...        ...          ...       ...     ...         ...
# 7995     1         4       1.75         2000      7350     1.0           0
# 7996     1         4       2.25         1870      6693     2.0           0
# 7997     1         2       1.00         1240      5500     1.0           0
# 7998     1         3       1.50         1280      2114     1.5           0
# 7999     1         3       2.25         1770      8165     2.0           0
#
# ...

# %%
train_3
# Out:
#       bias  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0        1         3       1.00         1020      7874     1.0           0
# 1        1         3       2.25         2210      8000     2.0           0
# 2        1         4       2.50         2350      5835     2.0           0
# 3        1         3       1.50         1660      4800     2.0           0
# 4        1         3       2.50         2410      9916     2.0           0
# ...    ...       ...        ...          ...       ...     ...         ...
# 7995     1         4       1.75         2000      7350     1.0           0
# 7996     1         4       2.25         1870      6693     2.0           0
# 7997     1         2       1.00         1240      5500     1.0           0
# 7998     1         3       1.50         1280      2114     1.5           0
# 7999     1         3       2.25         1770      8165     2.0           0
#
# ...

# %%
training_file_dir = os.path.join(os.getcwd(), "IA1_train.csv")
train = load_data(training_file_dir)

# %%
train_2 = load_data(training_file_dir)

# %%
training_file_dir = os.path.join(os.getcwd(), "IA1_train.csv")
train = load_data(training_file_dir)

# %%
os.path.join(os.getcwd(), "IA1_train")
# Out:
# 'C:\\Users\\paulm\\AI_534\\IA1_train'

# %%
train.drop(columns='id')
# Out:
#             date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      5/21/2014         3       1.00         1020      7874     1.0
# 1       6/9/2014         3       2.25         2210      8000     2.0
# 2      2/18/2015         4       2.50         2350      5835     2.0
# 3      5/22/2014         3       1.50         1660      4800     2.0
# 4       9/5/2014         3       2.50         2410      9916     2.0
# ...          ...       ...        ...          ...       ...     ...
# 7995   2/26/2015         4       1.75         2000      7350     1.0
# 7996   9/26/2014         4       2.25         1870      6693     2.0
# 7997  11/19/2014         2       1.00         1240      5500     1.0
# 7998  10/14/2014         3       1.50         1280      2114     1.5
# 7999    5/7/2014         3       2.25         1770      8165     2.0
#
#       waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# ...

# %%
train
# Out:
#               id        date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     7972604355   5/21/2014         3       1.00         1020      7874
# 1     8731951130    6/9/2014         3       2.25         2210      8000
# 2     7885800740   2/18/2015         4       2.50         2350      5835
# 3     4232900940   5/22/2014         3       1.50         1660      4800
# 4     3275850190    9/5/2014         3       2.50         2410      9916
# ...          ...         ...       ...        ...          ...       ...
# 7995  4222500410   2/26/2015         4       1.75         2000      7350
# 7996  1150700170   9/26/2014         4       2.25         1870      6693
# 7997  1959702045  11/19/2014         2       1.00         1240      5500
# 7998  7234601221  10/14/2014         3       1.50         1280      2114
# 7999  3275740030    5/7/2014         3       2.25         1770      8165
#
#       floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# ...

# %%
x = train.pop('id')

# %%
x
# Out:
# 0       7972604355
# 1       8731951130
# 2       7885800740
# 3       4232900940
# 4       3275850190
#            ...
# 7995    4222500410
# 7996    1150700170
# 7997    1959702045
# 7998    7234601221
# 7999    3275740030
# Name: id, Length: 8000, dtype: int64

# %%
train
# Out:
#             date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      5/21/2014         3       1.00         1020      7874     1.0
# 1       6/9/2014         3       2.25         2210      8000     2.0
# 2      2/18/2015         4       2.50         2350      5835     2.0
# 3      5/22/2014         3       1.50         1660      4800     2.0
# 4       9/5/2014         3       2.50         2410      9916     2.0
# ...          ...       ...        ...          ...       ...     ...
# 7995   2/26/2015         4       1.75         2000      7350     1.0
# 7996   9/26/2014         4       2.25         1870      6693     2.0
# 7997  11/19/2014         2       1.00         1240      5500     1.0
# 7998  10/14/2014         3       1.50         1280      2114     1.5
# 7999    5/7/2014         3       2.25         1770      8165     2.0
#
#       waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# ...

# %%
dates = train.pop('date')

# %%
train['year'] = [datetime.datetime.strptime(date, "%m/%d/%Y").year for date in dates]

# %%
type(dates[1])
# Out:
# str

# %%
train
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0            3       1.00         1020      7874     1.0           0     0
# 1            3       2.25         2210      8000     2.0           0     0
# 2            4       2.50         2350      5835     2.0           0     0
# 3            3       1.50         1660      4800     2.0           0     0
# 4            3       2.50         2410      9916     2.0           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 7995         4       1.75         2000      7350     1.0           0     0
# 7996         4       2.25         1870      6693     2.0           0     0
# 7997         2       1.00         1240      5500     1.0           0     0
# 7998         3       1.50         1280      2114     1.5           0     0
# 7999         3       2.25         1770      8165     2.0           0     0
#
# ...

# %%
train['day'] = [datetime.datetime.strptime(date, "%m/%d/%Y").day for date in dates]

# %%
train
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0            3       1.00         1020      7874     1.0           0     0
# 1            3       2.25         2210      8000     2.0           0     0
# 2            4       2.50         2350      5835     2.0           0     0
# 3            3       1.50         1660      4800     2.0           0     0
# 4            3       2.50         2410      9916     2.0           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 7995         4       1.75         2000      7350     1.0           0     0
# 7996         4       2.25         1870      6693     2.0           0     0
# 7997         2       1.00         1240      5500     1.0           0     0
# 7998         3       1.50         1280      2114     1.5           0     0
# 7999         3       2.25         1770      8165     2.0           0     0
#
# ...

# %%
train['month']=[datetime.datetime.strptime(date, "%m/%d/%Y").month for date in dates]

# %%
train
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0            3       1.00         1020      7874     1.0           0     0
# 1            3       2.25         2210      8000     2.0           0     0
# 2            4       2.50         2350      5835     2.0           0     0
# 3            3       1.50         1660      4800     2.0           0     0
# 4            3       2.50         2410      9916     2.0           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 7995         4       1.75         2000      7350     1.0           0     0
# 7996         4       2.25         1870      6693     2.0           0     0
# 7997         2       1.00         1240      5500     1.0           0     0
# 7998         3       1.50         1280      2114     1.5           0     0
# 7999         3       2.25         1770      8165     2.0           0     0
#
# ...

# %%
def proc(preprocess_data):
    preprocess_data['age_since_renovated'] = [y==0]
    
    label == "normal" ? :circle : :x,

    for i, year in enumerate(preprocess_data['yr_renovated']):
        if year == 0:
            year_built = cp.deepcopy(preprocess_data['yr_built'][i])
            preprocess_data['age_since_renovated'][i] = cp.deepcopy(year) - year_built
        else:
            year_renovated = cp.deepcopy(preprocess_data['yr_renovated'][i])
            preprocess_data['age_since_renovated'][i] = cp.deepcopy(year) - year_renovated

# %%
proc(train)
# Out:
# C:\Users\paulm\AppData\Local\Temp\ipykernel_25768\1042163333.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   preprocess_data['age_since_renovated'][i] = cp.deepcopy(year) - year_built
# C:\Users\paulm\AppData\Local\Temp\ipykernel_25768\1042163333.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   preprocess_data['age_since_renovated'][i] = cp.deepcopy(year) - year_renovated

# %%
train
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0            3       1.00         1020      7874     1.0           0     0
# 1            3       2.25         2210      8000     2.0           0     0
# 2            4       2.50         2350      5835     2.0           0     0
# 3            3       1.50         1660      4800     2.0           0     0
# 4            3       2.50         2410      9916     2.0           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 7995         4       1.75         2000      7350     1.0           0     0
# 7996         4       2.25         1870      6693     2.0           0     0
# 7997         2       1.00         1240      5500     1.0           0     0
# 7998         3       1.50         1280      2114     1.5           0     0
# 7999         3       2.25         1770      8165     2.0           0     0
#
# ...

# %%
train
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0            3       1.00         1020      7874     1.0           0     0
# 1            3       2.25         2210      8000     2.0           0     0
# 2            4       2.50         2350      5835     2.0           0     0
# 3            3       1.50         1660      4800     2.0           0     0
# 4            3       2.50         2410      9916     2.0           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 7995         4       1.75         2000      7350     1.0           0     0
# 7996         4       2.25         1870      6693     2.0           0     0
# 7997         2       1.00         1240      5500     1.0           0     0
# 7998         3       1.50         1280      2114     1.5           0     0
# 7999         3       2.25         1770      8165     2.0           0     0
#
# ...

# %%
def preprocess_data(data, normalize:bool=False, drop_sqrt_living15:bool=False):
    # Your code here:
    data["year"] = data["date"].dt.year
    data["month"] = data["date"].dt.month
    data["day"] = data["date"].dt.day
    data.insert(0, "bias", 1)
    data.drop(["id", "date"], axis=1, inplace=True)
    
    
    age_since_renovated = np.zeros(len(data))
    
    for (i, value) in enumerate(data["yr_renovated"]):
        if value==0:
            age_since_renovated[i] = data["year"][i] - data["yr_built"][i]
        else:
            age_since_renovated[i] = data["year"][i] - data["yr_renovated"][i]
            
    data["age_since_renovated"] = age_since_renovated
    
    
    if normalize:
        global params
        params = {}
        for col in data.columns:
            if col != "price" and col!= "waterfront" and col != "bias":
                μ = np.mean(data[col])
                σ = np.std(data[col])
                data[col] = (data[col] -μ)/ σ
                params[col] = (μ, σ)
                
    if drop_sqrt_living15:
        data.drop(sqrt_living15, axis=1, inplace=True)
     
    preprocessed_data = data.copy()  

    return preprocessed_data

# %%
preprocess_data(train_3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 preprocess_data(train_3)
#
# Input In [23], in preprocess_data(data, normalize, drop_sqrt_living15)
#       1 def preprocess_data(data, normalize:bool=False, drop_sqrt_living15:bool=False):
#       2     # Your code here:
# ----> 3     data["year"] = data["date"].dt.year
#       4     data["month"] = data["date"].dt.month
#       5     data["day"] = data["date"].dt.day
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# ...

# %%
def plot_losses(losses, learning_rates):
    fig, ax = plt.subplots()
    plt.ylabel('loss')
    plt.xlabel('iteration')

    for i, loss in enumerate(losses):
        line = plt.plot(loss, label=f"γ={learning_rates[i]}")
        
    ax.legend(loc='upper right')
    plt.show()

# %%
stupid_losses = [[1, 2, 3, 4], [4, 2, 2, 3]]
learning_rates = [1, 9]

plot_losses(stupid_losses, learning_rates)

# %%
learning_rates = [10**(-i) for i in [0, 1, 2, 3, 4]]

# %%
learning_rates
# Out:
# [1, 0.1, 0.01, 0.001, 0.0001]

# %%
test = [0]*10
test[5] = "test"
test
# Out:
# [0, 0, 0, 0, 0, 'test', 0, 0, 0, 0]

# %%
some_dict = {
    "a" : 1,
    "b" : 2
}

for i, (key, value) in enumerate(some_dict):
    print(i, key, value)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [116], in <cell line: 6>()
#       1 some_dict = {
#       2     "a" : 1,
#       3     "b" : 2
#       4 }
# ----> 6 for i, (key, value) in enumerate(some_dict):
#       7     print(i, key, value)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
[10**(-i) for i in [0.1*j for j in range(0, 3081)]]
# Out:
# [1.0,
#  0.7943282347242815,
#  0.6309573444801932,
#  0.5011872336272722,
#  0.3981071705534972,
#  0.31622776601683794,
#  0.25118864315095796,
#  0.19952623149688792,
#  0.15848931924611134,
#  0.12589254117941673,
#  0.1,
#  0.07943282347242814,
#  0.0630957344480193,
#  0.05011872336272722,
#  0.03981071705534971,
#  0.03162277660168379,
#  0.025118864315095794,
#  0.01995262314968879,
#  0.015848931924611134,
#  0.012589254117941668,
#  0.01,
#  0.007943282347242814,
#  0.00630957344480193,
#  0.005011872336272719,
#  0.003981071705534969,
#  0.0031622776601683794,
#  0.0025118864315095794,
#  0.001995262314968879,
#  0.0015848931924611126,
#  0.0012589254117941662,
#  0.001,
#  0.0007943282347242813,
#  0.000630957344480193,
#  0.000501187233627272,
#  0.0003981071705534969,
#  0.00031622776601683794,
#  0.00025118864315095795,
#  0.00019952623149688788,
#  0.00015848931924611126,
#  0.0001258925411794166,
#  0.0001,
#  7.943282347242806e-05,
#  6.309573444801929e-05,
# ...
